# %%
import pandas as pd
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats=np.random.uniform(-90,90,2000)
lngs=np.random.uniform(-180,180,2000)
lats_lngs=zip(lats,lngs)
coordinates=list(lats_lngs)

# %%
cities=[]
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
city_data=[]
print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count=1
set_count=1
for i,city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url=url+"&q="+city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count=record_count+1
    try:
        city_weather=requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country=city_weather["sys"]["country"]
        weather_description=city_weather["weather"][0]["description"]
        city_data.append({"City":city.title(),
                         "Country":city_country,
                         "Lat":city_lat,
                         "Lng":city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed":city_wind,
                         "Current Description":weather_description})
    except:
        print("City not found. Skipping...")
        pass
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | zemio
# Processing Record 7 of Set 1 | fairbanks
# Processing Record 8 of Set 1 | lemesos
# City not found. Skipping...
# Processing Record 9 of Set 1 | atbasar
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | baculin
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | sigli
# Processing Record 14 of Set 1 | fortuna
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | oranjestad
# Processing Record 19 of Set 1 | uige
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | pisco
# Processing Record 24 of Set 1 | ferme-neuve
# Processing Record 25 of Set 1 | natal
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | gaoua
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 1 | abapo
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | bosaso
# Processing Record 38 of Set 1 | lahaina
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | lubango
# Processing Record 41 of Set 1 | cam ranh
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | sinnamary
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | ilinskiy
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | boueni
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | kavaratti
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | thai binh
# Processing Record 5 of Set 2 | samarai
# Processing Record 6 of Set 2 | tura
# Processing Record 7 of Set 2 | gravdal
# Processing Record 8 of Set 2 | cotusca
# Processing Record 9 of Set 2 | bilibino
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | tamiahua
# Processing Record 12 of Set 2 | winnemucca
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | coihaique
# Processing Record 15 of Set 2 | talara
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | half moon bay
# Processing Record 18 of Set 2 | carutapera
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | vardo
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | rudnichnyy
# Processing Record 25 of Set 2 | ahipara
# Processing Record 26 of Set 2 | sawtell
# Processing Record 27 of Set 2 | aleksandrovka
# Processing Record 28 of Set 2 | hirado
# Processing Record 29 of Set 2 | namibe
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | faya
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | moron
# Processing Record 37 of Set 2 | lerwick
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | the valley
# Processing Record 40 of Set 2 | sangar
# Processing Record 41 of Set 2 | port lincoln
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | ust-tsilma
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | labuhan
# Processing Record 46 of Set 2 | cockburn town
# Processing Record 47 of Set 2 | morgantown
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | pevek
# Processing Record 50 of Set 2 | grand gaube
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | ust-kuyga
# Processing Record 3 of Set 3 | leningradskiy
# Processing Record 4 of Set 3 | kokopo
# Processing Record 5 of Set 3 | guerrero negro
# Processing Record 6 of Set 3 | boa vista
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | barabai
# Processing Record 9 of Set 3 | guadalupe victoria
# Processing Record 10 of Set 3 | pangkalanbuun
# Processing Record 11 of Set 3 | mareeba
# Processing Record 12 of Set 3 | aleksandrovskoye
# Processing Record 13 of Set 3 | souillac
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | naze
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | anadyr
# Processing Record 19 of Set 3 | kimparana
# Processing Record 20 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 3 | haines junction
# Processing Record 22 of Set 3 | batagay-alyta
# Processing Record 23 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | manokwari
# Processing Record 26 of Set 3 | sanghar
# Processing Record 27 of Set 3 | moreira sales
# Processing Record 28 of Set 3 | bandarbeyla
# Processing Record 29 of Set 3 | clyde river
# Processing Record 30 of Set 3 | nouadhibou
# Processing Record 31 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 3 | qaqortoq
# Processing Record 33 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | harker heights
# Processing Record 37 of Set 3 | necochea
# Processing Record 38 of Set 3 | ahuimanu
# Processing Record 39 of Set 3 | lasa
# Processing Record 40 of Set 3 | diego de almagro
# Processing Record 41 of Set 3 | srednekolymsk
# Processing Record 42 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 3 | paamiut
# Processing Record 44 of Set 3 | damietta
# Processing Record 45 of Set 3 | port blair
# Processing Record 46 of Set 3 | provideniya
# Processing Record 47 of Set 3 | vaini
# Processing Record 48 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 3 | sabha
# Processing Record 50 of Set 3 | comodoro rivadavia
# Processing Record 1 of Set 4 | kurilsk
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | mitchell
# Processing Record 4 of Set 4 | balykshi
# Processing Record 5 of Set 4 | concepcion
# Processing Record 6 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 4 | maldonado
# Processing Record 8 of Set 4 | vestmanna
# Processing Record 9 of Set 4 | sept-iles
# Processing Record 10 of Set 4 | cuenca
# Processing Record 11 of Set 4 | svetlaya
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | abha
# Processing Record 14 of Set 4 | verkhoyansk
# Processing Record 15 of Set 4 | havelock
# Processing Record 16 of Set 4 | kamaishi
# Processing Record 17 of Set 4 | sioux lookout
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | stromness
# Processing Record 20 of Set 4 | kodiak
# Processing Record 21 of Set 4 | lagoa
# Processing Record 22 of Set 4 | yakima
# Processing Record 23 of Set 4 | tangping
# Processing Record 24 of Set 4 | las matas de farfan
# Processing Record 25 of Set 4 | elko
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | grahamstown
# Processing Record 29 of Set 4 | wasilla
# Processing Record 30 of Set 4 | rassvet
# Processing Record 31 of Set 4 | goderich
# Processing Record 32 of Set 4 | mar del plata
# Processing Record 33 of Set 4 | macau
# Processing Record 34 of Set 4 | loviisa
# Processing Record 35 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | luwuk
# Processing Record 39 of Set 4 | salalah
# Processing Record 40 of Set 4 | pointe-noire
# Processing Record 41 of Set 4 | magaria
# Processing Record 42 of Set 4 | porto novo
# Processing Record 43 of Set 4 | bathsheba
# Processing Record 44 of Set 4 | klaksvik
# Processing Record 45 of Set 4 | aykhal
# Processing Record 46 of Set 4 | berlevag
# Processing Record 47 of Set 4 | mahaicony
# City not found. Skipping...
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | bucerias
# Processing Record 50 of Set 4 | tual
# Processing Record 1 of Set 5 | acajutla
# Processing Record 2 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 5 | rio grande
# Processing Record 4 of Set 5 | los llanos de aridane
# Processing Record 5 of Set 5 | juegang
# Processing Record 6 of Set 5 | praia da vitoria
# Processing Record 7 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | inirida
# Processing Record 12 of Set 5 | san cristobal
# Processing Record 13 of Set 5 | desnogorsk
# Processing Record 14 of Set 5 | yumen
# Processing Record 15 of Set 5 | killam
# Processing Record 16 of Set 5 | nuuk
# Processing Record 17 of Set 5 | yeppoon
# Processing Record 18 of Set 5 | nogliki
# Processing Record 19 of Set 5 | murgab
# Processing Record 20 of Set 5 | sondrio
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | boyolangu
# Processing Record 23 of Set 5 | ereymentau
# Processing Record 24 of Set 5 | ayan
# Processing Record 25 of Set 5 | zweibrucken
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | kenai
# Processing Record 28 of Set 5 | freiberg
# Processing Record 29 of Set 5 | shenjiamen
# Processing Record 30 of Set 5 | aksehir
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | port elizabeth
# Processing Record 33 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 34 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 35 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 36 of Set 5 | kendari
# Processing Record 37 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 5 | chichimila
# Processing Record 39 of Set 5 | mercedes
# Processing Record 40 of Set 5 | chisindia
# Processing Record 41 of Set 5 | broken hill
# Processing Record 42 of Set 5 | riyadh
# Processing Record 43 of Set 5 | bodden town
# Processing Record 44 of Set 5 | kirovskiy
# Processing Record 45 of Set 5 | iqaluit
# Processing Record 46 of Set 5 | faanui
# Processing Record 47 of Set 5 | sikasso
# Processing Record 48 of Set 5 | kaniama
# Processing Record 49 of Set 5 | chuy
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | la mira
# Processing Record 2 of Set 6 | bambous virieux
# Processing Record 3 of Set 6 | sitka
# Processing Record 4 of Set 6 | hamilton
# Processing Record 5 of Set 6 | newport
# Processing Record 6 of Set 6 | inhambane
# Processing Record 7 of Set 6 | chaozhou
# Processing Record 8 of Set 6 | anamur
# Processing Record 9 of Set 6 | revelstoke
# Processing Record 10 of Set 6 | gao
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | charters towers
# Processing Record 13 of Set 6 | yarkovo
# Processing Record 14 of Set 6 | vallenar
# Processing Record 15 of Set 6 | kargat
# Processing Record 16 of Set 6 | nykobing
# City not found. Skipping...
# Processing Record 17 of Set 6 | pyu
# Processing Record 18 of Set 6 | shitanjing
# Processing Record 19 of Set 6 | myronivka
# Processing Record 20 of Set 6 | fort-shevchenko
# Processing Record 21 of Set 6 | bogorodskoye
# Processing Record 22 of Set 6 | mufulira
# Processing Record 23 of Set 6 | lakhnadon
# Processing Record 24 of Set 6 | resen
# Processing Record 25 of Set 6 | mirandopolis
# Processing Record 26 of Set 6 | chokurdakh
# Processing Record 27 of Set 6 | kununurra
# Processing Record 28 of Set 6 | sao jose da coroa grande
# Processing Record 29 of Set 6 | kushmurun
# Processing Record 30 of Set 6 | gizo
# Processing Record 31 of Set 6 | gavle
# Processing Record 32 of Set 6 | nabire
# Processing Record 33 of Set 6 | mitsamiouli
# Processing Record 34 of Set 6 | gigmoto
# Processing Record 35 of Set 6 | bridlington
# Processing Record 36 of Set 6 | tuatapere
# Processing Record 37 of Set 6 | solvychegodsk
# Processing Record 38 of Set 6 | thinadhoo
# Processing Record 39 of Set 6 | lavrentiya
# Processing Record 40 of Set 6 | srivardhan
# Processing Record 41 of Set 6 | high level
# Processing Record 42 of Set 6 | misratah
# Processing Record 43 of Set 6 | ostrovnoy
# Processing Record 44 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 6 | talah
# City not found. Skipping...
# Processing Record 46 of Set 6 | ponta delgada
# Processing Record 47 of Set 6 | marawi
# Processing Record 48 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 6 | colquechaca
# Processing Record 1 of Set 7 | troyes
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 7 | predivinsk
# Processing Record 5 of Set 7 | billings
# Processing Record 6 of Set 7 | auburn
# Processing Record 7 of Set 7 | itoman
# Processing Record 8 of Set 7 | mecca
# Processing Record 9 of Set 7 | coleraine
# Processing Record 10 of Set 7 | manggar
# Processing Record 11 of Set 7 | neijiang
# Processing Record 12 of Set 7 | santa cruz
# Processing Record 13 of Set 7 | japura
# Processing Record 14 of Set 7 | thanh hoa
# Processing Record 15 of Set 7 | east london
# Processing Record 16 of Set 7 | iranshahr
# Processing Record 17 of Set 7 | veraval
# Processing Record 18 of Set 7 | henties bay
# Processing Record 19 of Set 7 | kumluca
# Processing Record 20 of Set 7 | codrington
# Processing Record 21 of Set 7 | samfya
# Processing Record 22 of Set 7 | ferrol
# Processing Record 23 of Set 7 | tongliao
# Processing Record 24 of Set 7 | tanda
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | severnoye
# Processing Record 27 of Set 7 | tias
# Processing Record 28 of Set 7 | saint john
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | harnoli
# Processing Record 31 of Set 7 | saint george
# Processing Record 32 of Set 7 | sorland
# Processing Record 33 of Set 7 | vila franca do campo
# Processing Record 34 of Set 7 | lixourion
# Processing Record 35 of Set 7 | rio gallegos
# Processing Record 36 of Set 7 | nishihara
# Processing Record 37 of Set 7 | nizhniy baskunchak
# Processing Record 38 of Set 7 | esil
# Processing Record 39 of Set 7 | nyaunglebin
# Processing Record 40 of Set 7 | miraflores
# Processing Record 41 of Set 7 | whitehorse
# Processing Record 42 of Set 7 | joshimath
# Processing Record 43 of Set 7 | dunedin
# Processing Record 44 of Set 7 | torbay
# Processing Record 45 of Set 7 | salamanca
# Processing Record 46 of Set 7 | saiha
# Processing Record 47 of Set 7 | matata
# Processing Record 48 of Set 7 | andros town
# Processing Record 49 of Set 7 | sayan
# Processing Record 50 of Set 7 | kapuskasing
# Processing Record 1 of Set 8 | michigan city
# Processing Record 2 of Set 8 | uk
# City not found. Skipping...
# Processing Record 3 of Set 8 | griffin
# Processing Record 4 of Set 8 | makakilo city
# Processing Record 5 of Set 8 | rawson
# Processing Record 6 of Set 8 | bazarnyye mataki
# Processing Record 7 of Set 8 | wagar
# Processing Record 8 of Set 8 | roald
# Processing Record 9 of Set 8 | jacksonville
# Processing Record 10 of Set 8 | lashio
# Processing Record 11 of Set 8 | katsuura
# Processing Record 12 of Set 8 | sinegorye
# Processing Record 13 of Set 8 | north ogden
# Processing Record 14 of Set 8 | sorsk
# Processing Record 15 of Set 8 | guarapari
# Processing Record 16 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 8 | kiunga
# Processing Record 18 of Set 8 | parlakimidi
# Processing Record 19 of Set 8 | namatanai
# Processing Record 20 of Set 8 | tigre
# Processing Record 21 of Set 8 | lovozero
# Processing Record 22 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 8 | northam
# Processing Record 24 of Set 8 | fukue
# Processing Record 25 of Set 8 | wodonga
# Processing Record 26 of Set 8 | dennis
# Processing Record 27 of Set 8 | aljezur
# Processing Record 28 of Set 8 | chiang kham
# Processing Record 29 of Set 8 | mahibadhoo
# Processing Record 30 of Set 8 | nileshwar
# Processing Record 31 of Set 8 | buraydah
# Processing Record 32 of Set 8 | eenhana
# Processing Record 33 of Set 8 | tubuala
# Processing Record 34 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 8 | isangel
# Processing Record 36 of Set 8 | omagari
# Processing Record 37 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 38 of Set 8 | pangody
# Processing Record 39 of Set 8 | concarneau
# Processing Record 40 of Set 8 | kahului
# Processing Record 41 of Set 8 | zhigansk
# Processing Record 42 of Set 8 | bijar
# Processing Record 43 of Set 8 | simbahan
# Processing Record 44 of Set 8 | bauchi
# Processing Record 45 of Set 8 | san juan
# Processing Record 46 of Set 8 | del rio
# Processing Record 47 of Set 8 | mayo
# Processing Record 48 of Set 8 | nadym
# Processing Record 49 of Set 8 | kilimatinde
# Processing Record 50 of Set 8 | araouane
# Processing Record 1 of Set 9 | saint-augustin
# Processing Record 2 of Set 9 | manor
# Processing Record 3 of Set 9 | hambantota
# Processing Record 4 of Set 9 | gornozavodsk
# Processing Record 5 of Set 9 | sur
# Processing Record 6 of Set 9 | bokoro
# Processing Record 7 of Set 9 | beringovskiy
# Processing Record 8 of Set 9 | asilah
# Processing Record 9 of Set 9 | juneau
# Processing Record 10 of Set 9 | waipawa
# Processing Record 11 of Set 9 | avera
# Processing Record 12 of Set 9 | beyneu
# Processing Record 13 of Set 9 | shenandoah
# Processing Record 14 of Set 9 | horodkivka
# Processing Record 15 of Set 9 | apollonia
# Processing Record 16 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 9 | palana
# Processing Record 18 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 9 | ambilobe
# Processing Record 20 of Set 9 | garissa
# Processing Record 21 of Set 9 | sredec
# City not found. Skipping...
# Processing Record 22 of Set 9 | sechura
# Processing Record 23 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 9 | quatre cocos
# Processing Record 25 of Set 9 | irece
# Processing Record 26 of Set 9 | andenes
# Processing Record 27 of Set 9 | vanavara
# Processing Record 28 of Set 9 | fort frances
# Processing Record 29 of Set 9 | tiksi
# Processing Record 30 of Set 9 | luxor
# Processing Record 31 of Set 9 | atar
# Processing Record 32 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 33 of Set 9 | waingapu
# Processing Record 34 of Set 9 | nanortalik
# Processing Record 35 of Set 9 | sabang
# Processing Record 36 of Set 9 | esperance
# Processing Record 37 of Set 9 | buala
# Processing Record 38 of Set 9 | xichang
# Processing Record 39 of Set 9 | mount isa
# Processing Record 40 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 9 | gijon
# Processing Record 42 of Set 9 | saint anthony
# Processing Record 43 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 9 | neryungri
# Processing Record 46 of Set 9 | monrovia
# Processing Record 47 of Set 9 | kavieng
# Processing Record 48 of Set 9 | lima
# Processing Record 49 of Set 9 | huangpi
# Processing Record 50 of Set 9 | lisakovsk
# Processing Record 1 of Set 10 | rubio
# Processing Record 2 of Set 10 | pasni
# Processing Record 3 of Set 10 | baturaja
# Processing Record 4 of Set 10 | roma
# Processing Record 5 of Set 10 | talnakh
# Processing Record 6 of Set 10 | posse
# Processing Record 7 of Set 10 | sawakin
# Processing Record 8 of Set 10 | champerico
# Processing Record 9 of Set 10 | pishin
# Processing Record 10 of Set 10 | auki
# Processing Record 11 of Set 10 | sao sebastiao do cai
# Processing Record 12 of Set 10 | solnechnyy
# Processing Record 13 of Set 10 | dekar
# Processing Record 14 of Set 10 | rabo de peixe
# Processing Record 15 of Set 10 | koslan
# Processing Record 16 of Set 10 | sisimiut
# Processing Record 17 of Set 10 | zaysan
# Processing Record 18 of Set 10 | beziers
# Processing Record 19 of Set 10 | kayerkan
# Processing Record 20 of Set 10 | krasnogorskoye
# Processing Record 21 of Set 10 | kudahuvadhoo
# Processing Record 22 of Set 10 | vyazemskiy
# Processing Record 23 of Set 10 | great yarmouth
# Processing Record 24 of Set 10 | biltine
# Processing Record 25 of Set 10 | catemaco
# Processing Record 26 of Set 10 | nome
# Processing Record 27 of Set 10 | hobyo
# Processing Record 28 of Set 10 | kruisfontein
# Processing Record 29 of Set 10 | dalkola
# Processing Record 30 of Set 10 | teahupoo
# Processing Record 31 of Set 10 | anshun
# Processing Record 32 of Set 10 | port-gentil
# Processing Record 33 of Set 10 | nyimba
# Processing Record 34 of Set 10 | san angelo
# Processing Record 35 of Set 10 | ndele
# Processing Record 36 of Set 10 | bossembele
# City not found. Skipping...
# Processing Record 37 of Set 10 | havre-saint-pierre
# Processing Record 38 of Set 10 | antofagasta
# Processing Record 39 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 10 | evensk
# Processing Record 41 of Set 10 | palamos
# Processing Record 42 of Set 10 | trinidad
# Processing Record 43 of Set 10 | taltal
# Processing Record 44 of Set 10 | tazovskiy
# Processing Record 45 of Set 10 | dhidhdhoo
# Processing Record 46 of Set 10 | carroll
# Processing Record 47 of Set 10 | krasnoborsk
# Processing Record 48 of Set 10 | okahandja
# Processing Record 49 of Set 10 | bambanglipuro
# Processing Record 50 of Set 10 | campi bisenzio
# Processing Record 1 of Set 11 | sayyan
# Processing Record 2 of Set 11 | hovd
# Processing Record 3 of Set 11 | tygda
# Processing Record 4 of Set 11 | camocim
# Processing Record 5 of Set 11 | road town
# Processing Record 6 of Set 11 | ushumun
# Processing Record 7 of Set 11 | ixtapa
# Processing Record 8 of Set 11 | marsabit
# Processing Record 9 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 11 | meadow lake
# Processing Record 14 of Set 11 | lata
# Processing Record 15 of Set 11 | okha
# Processing Record 16 of Set 11 | ulladulla
# Processing Record 17 of Set 11 | maraa
# Processing Record 18 of Set 11 | ardakan
# Processing Record 19 of Set 11 | clarence town
# Processing Record 20 of Set 11 | colac
# Processing Record 21 of Set 11 | kisoro
# Processing Record 22 of Set 11 | korla
# Processing Record 23 of Set 11 | talalayivka
# Processing Record 24 of Set 11 | nalgonda
# Processing Record 25 of Set 11 | pacific grove
# Processing Record 26 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 11 | porto seguro
# Processing Record 28 of Set 11 | halifax
# Processing Record 29 of Set 11 | fort nelson
# Processing Record 30 of Set 11 | reconquista
# Processing Record 31 of Set 11 | karpathos
# Processing Record 32 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 11 | verkhniy landekh
# Processing Record 34 of Set 11 | ewa beach
# Processing Record 35 of Set 11 | imisli
# City not found. Skipping...
# Processing Record 36 of Set 11 | amlagora
# Processing Record 37 of Set 11 | roseto degli abruzzi
# Processing Record 38 of Set 11 | henderson
# Processing Record 39 of Set 11 | morden
# Processing Record 40 of Set 11 | bandar penggaram
# City not found. Skipping...
# Processing Record 41 of Set 11 | ko samui
# Processing Record 42 of Set 11 | puerto colombia
# Processing Record 43 of Set 11 | southbridge
# Processing Record 44 of Set 11 | grootfontein
# Processing Record 45 of Set 11 | ilhabela
# Processing Record 46 of Set 11 | tiznit
# Processing Record 47 of Set 11 | galesong
# Processing Record 48 of Set 11 | sumter
# Processing Record 49 of Set 11 | batticaloa
# Processing Record 50 of Set 11 | wucheng
# Processing Record 1 of Set 12 | christchurch
# Processing Record 2 of Set 12 | sakakah
# Processing Record 3 of Set 12 | east angus
# Processing Record 4 of Set 12 | gat
# Processing Record 5 of Set 12 | nargana
# Processing Record 6 of Set 12 | vazante
# Processing Record 7 of Set 12 | dutlwe
# Processing Record 8 of Set 12 | ust-shonosha
# Processing Record 9 of Set 12 | jalingo
# Processing Record 10 of Set 12 | mabaruma
# Processing Record 11 of Set 12 | norman wells
# Processing Record 12 of Set 12 | kyaukse
# Processing Record 13 of Set 12 | tomatlan
# Processing Record 14 of Set 12 | nuqui
# Processing Record 15 of Set 12 | mutsu
# Processing Record 16 of Set 12 | gimli
# Processing Record 17 of Set 12 | nagua
# Processing Record 18 of Set 12 | willowmore
# Processing Record 19 of Set 12 | qeshm
# Processing Record 20 of Set 12 | santa fe
# Processing Record 21 of Set 12 | bras-panon
# Processing Record 22 of Set 12 | yerbogachen
# Processing Record 23 of Set 12 | koungou
# Processing Record 24 of Set 12 | chichibu
# Processing Record 25 of Set 12 | iquitos
# Processing Record 26 of Set 12 | tsabong
# Processing Record 27 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 12 | aquiraz
# Processing Record 29 of Set 12 | prince rupert
# Processing Record 30 of Set 12 | tautira
# Processing Record 31 of Set 12 | pochutla
# Processing Record 32 of Set 12 | cabedelo
# Processing Record 33 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 12 | barra patuca
# Processing Record 35 of Set 12 | key west
# Processing Record 36 of Set 12 | batagay
# Processing Record 37 of Set 12 | la ronge
# Processing Record 38 of Set 12 | zhob
# Processing Record 39 of Set 12 | te anau
# Processing Record 40 of Set 12 | fare
# Processing Record 41 of Set 12 | tessalit
# Processing Record 42 of Set 12 | mirnyy
# Processing Record 43 of Set 12 | wamba
# Processing Record 44 of Set 12 | aginskoye
# Processing Record 45 of Set 12 | djenne
# Processing Record 46 of Set 12 | inuvik
# Processing Record 47 of Set 12 | epe
# Processing Record 48 of Set 12 | port-cartier
# Processing Record 49 of Set 12 | voh
# Processing Record 50 of Set 12 | albert lea
# Processing Record 1 of Set 13 | rocha
# Processing Record 2 of Set 13 | katangli
# Processing Record 3 of Set 13 | mahuva
# Processing Record 4 of Set 13 | santa maria
# Processing Record 5 of Set 13 | arroyo
# Processing Record 6 of Set 13 | druzhnaya gorka
# Processing Record 7 of Set 13 | mehamn
# Processing Record 8 of Set 13 | aranos
# Processing Record 9 of Set 13 | aran
# Processing Record 10 of Set 13 | shache
# Processing Record 11 of Set 13 | calamar
# Processing Record 12 of Set 13 | nichinan
# Processing Record 13 of Set 13 | meulaboh
# Processing Record 14 of Set 13 | avare
# Processing Record 15 of Set 13 | rhyl
# Processing Record 16 of Set 13 | khokhlovo
# Processing Record 17 of Set 13 | tammisaari
# Processing Record 18 of Set 13 | kantang
# Processing Record 19 of Set 13 | volchansk
# Processing Record 20 of Set 13 | ostersund
# Processing Record 21 of Set 13 | vredendal
# Processing Record 22 of Set 13 | dasoguz
# Processing Record 23 of Set 13 | kerema
# Processing Record 24 of Set 13 | la crosse
# Processing Record 25 of Set 13 | soria
# Processing Record 26 of Set 13 | leh
# Processing Record 27 of Set 13 | brae
# Processing Record 28 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 29 of Set 13 | general zuazua
# Processing Record 30 of Set 13 | acapulco
# Processing Record 31 of Set 13 | grindavik
# Processing Record 32 of Set 13 | duldurga
# Processing Record 33 of Set 13 | kitui
# Processing Record 34 of Set 13 | braintree
# Processing Record 35 of Set 13 | alta floresta
# Processing Record 36 of Set 13 | quang ngai
# Processing Record 37 of Set 13 | teya
# Processing Record 38 of Set 13 | motygino
# Processing Record 39 of Set 13 | kloulklubed
# Processing Record 40 of Set 13 | patnos
# Processing Record 41 of Set 13 | mount pleasant
# Processing Record 42 of Set 13 | salym
# Processing Record 43 of Set 13 | yamada
# Processing Record 44 of Set 13 | owando
# Processing Record 45 of Set 13 | tamuin
# Processing Record 46 of Set 13 | honiara
# Processing Record 47 of Set 13 | tecoanapa
# Processing Record 48 of Set 13 | kijang
# Processing Record 49 of Set 13 | orlovskiy
# Processing Record 50 of Set 13 | marsh harbour
# Processing Record 1 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 2 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 14 | ilanskiy
# Processing Record 5 of Set 14 | kasongo-lunda
# Processing Record 6 of Set 14 | ryotsu
# Processing Record 7 of Set 14 | bedele
# Processing Record 8 of Set 14 | ishigaki
# Processing Record 9 of Set 14 | weligama
# Processing Record 10 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 11 of Set 14 | vostok
# Processing Record 12 of Set 14 | esmeralda
# Processing Record 13 of Set 14 | alampur
# Processing Record 14 of Set 14 | saint-joseph
# Processing Record 15 of Set 14 | antissa
# City not found. Skipping...
# Processing Record 16 of Set 14 | olafsvik
# Processing Record 17 of Set 14 | den helder
# Processing Record 18 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 14 | phan thiet
# Processing Record 20 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 21 of Set 14 | doha
# Processing Record 22 of Set 14 | menongue
# Processing Record 23 of Set 14 | banjar
# Processing Record 24 of Set 14 | camacupa
# Processing Record 25 of Set 14 | poum
# Processing Record 26 of Set 14 | sokolo
# Processing Record 27 of Set 14 | kailua
# Processing Record 28 of Set 14 | kalga
# Processing Record 29 of Set 14 | college
# Processing Record 30 of Set 14 | ihosy
# Processing Record 31 of Set 14 | pyapon
# Processing Record 32 of Set 14 | altagracia de orituco
# Processing Record 33 of Set 14 | ketchikan
# Processing Record 34 of Set 14 | abalak
# Processing Record 35 of Set 14 | naryan-mar
# Processing Record 36 of Set 14 | husavik
# Processing Record 37 of Set 14 | buchanan
# Processing Record 38 of Set 14 | kidal
# Processing Record 39 of Set 14 | williams lake
# Processing Record 40 of Set 14 | behshahr
# Processing Record 41 of Set 14 | guantanamo
# Processing Record 42 of Set 14 | broome
# Processing Record 43 of Set 14 | luanda
# Processing Record 44 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 14 | kon tum
# Processing Record 46 of Set 14 | opuwo
# Processing Record 47 of Set 14 | hay river
# Processing Record 48 of Set 14 | campbell river
# Processing Record 49 of Set 14 | coahuayana
# Processing Record 50 of Set 14 | bunbury
# Processing Record 1 of Set 15 | marzuq
# Processing Record 2 of Set 15 | gorom-gorom
# Processing Record 3 of Set 15 | garden city
# Processing Record 4 of Set 15 | flinders
# Processing Record 5 of Set 15 | vao
# Processing Record 6 of Set 15 | mandapam
# Processing Record 7 of Set 15 | karratha
# Processing Record 8 of Set 15 | along
# Processing Record 9 of Set 15 | laguna
# Processing Record 10 of Set 15 | las cruces
# Processing Record 11 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 12 of Set 15 | areosa
# Processing Record 13 of Set 15 | coquimbo
# Processing Record 14 of Set 15 | kinlochleven
# Processing Record 15 of Set 15 | ancud
# Processing Record 16 of Set 15 | grants
# Processing Record 17 of Set 15 | silos
# Processing Record 18 of Set 15 | vila velha
# Processing Record 19 of Set 15 | san ramon
# Processing Record 20 of Set 15 | brandon
# Processing Record 21 of Set 15 | paciran
# Processing Record 22 of Set 15 | oksfjord
# Processing Record 23 of Set 15 | katobu
# Processing Record 24 of Set 15 | sol-iletsk
# Processing Record 25 of Set 15 | niigata
# Processing Record 26 of Set 15 | jieshi
# Processing Record 27 of Set 15 | tongren
# Processing Record 28 of Set 15 | rabaul
# Processing Record 29 of Set 15 | san carlos de bariloche
# Processing Record 30 of Set 15 | martapura
# Processing Record 31 of Set 15 | moindou
# Processing Record 32 of Set 15 | bonthe
# Processing Record 33 of Set 15 | malakal
# Processing Record 34 of Set 15 | tolmachevo
# Processing Record 35 of Set 15 | bayir
# Processing Record 36 of Set 15 | florence
# Processing Record 37 of Set 15 | kalmunai
# Processing Record 38 of Set 15 | varazdin
# Processing Record 39 of Set 15 | tiguisan
# Processing Record 40 of Set 15 | kamen-na-obi
# Processing Record 41 of Set 15 | parabel
# Processing Record 42 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 43 of Set 15 | eydhafushi
# Processing Record 44 of Set 15 | san vicente
# Processing Record 45 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 46 of Set 15 | yar-sale
# Processing Record 47 of Set 15 | copiapo
# Processing Record 48 of Set 15 | dharchula
# Processing Record 49 of Set 15 | hudiksvall
# Processing Record 50 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 16 | rosario
# Processing Record 2 of Set 16 | pelotas
# Processing Record 3 of Set 16 | hirara
# Processing Record 4 of Set 16 | tapes
# Processing Record 5 of Set 16 | kormilovka
# Processing Record 6 of Set 16 | suez
# Processing Record 7 of Set 16 | pangnirtung
# Processing Record 8 of Set 16 | jaramana
# City not found. Skipping...
# Processing Record 9 of Set 16 | severo-yeniseyskiy
# Processing Record 10 of Set 16 | leova
# Processing Record 11 of Set 16 | axixa do tocantins
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Nikolskoye      RU  59.7035   30.7861     49.89        91         100
# 1  Georgetown      MY   5.4112  100.3354     81.90        90          20
# 2    Hermanus      ZA -34.4187   19.2345     62.80        85          29
# 3      Hasaki      JP  35.7333  140.8333     68.40        60         100
# 4   Busselton      AU -33.6500  115.3333     51.08        89          76
#
#    Wind Speed Current Description
# 0        9.22     overcast clouds
# 1        3.00          few clouds
# 2       12.75    scattered clouds
# 3       13.65     overcast clouds
# 4        5.23       broken clouds

# %%
output_data_file="WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
